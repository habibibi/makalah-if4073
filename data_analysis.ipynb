# %%
import pandas as pd
df = pd.read_csv('data.csv')

# %%
df.describe()
# Out:
#              l_mean         l_std        s_mean         s_std     l_entropy  \
# count  10725.000000  10725.000000  10725.000000  10725.000000  10725.000000
# mean     112.611061     48.010473     55.329689     54.601122      6.257184
# std       61.926307     24.066265     34.230668     25.567127      1.198200
# min        0.000000      0.000000      0.000000      0.000000     -0.000000
# 25%       59.391078     28.368009     30.562617     33.452710      5.722302
# 50%      118.148398     52.549106     47.109388     50.845051      6.567944
# 75%      165.391641     67.452388     71.039344     74.471282      7.125758
# max      247.350000    112.481405    235.252088    125.721086      7.842582
#
#           s_entropy         class
# count  10725.000000  10725.000000
# mean       5.675361      2.000000
# std        1.090381      1.414279
# min       -0.000000      0.000000
# 25%        5.188562      1.000000
# 50%        5.869378      2.000000
# 75%        6.418549      3.000000
# max        7.692869      4.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns


corr_matrix = df.corr()

# Create a heatmap
plt.figure(figsize=(8, 6))  # Adjust size
sns.heatmap(
    corr_matrix,
    annot=True,              # Show correlation values
    fmt=".2f",               # Format to 2 decimal places
    cmap="coolwarm",         # Color map
    cbar=True,               # Show color bar
    linewidths=0.5,          # Add gridlines
    square=True,             # Keep cells square
    annot_kws={"size": 10},  # Adjust annotation font size
)

plt.title("Correlation Matrix", fontsize=16)  # Add title
plt.show()
